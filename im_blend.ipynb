# %%
import skimage.io as io
from skimage import color
from skimage.transform import rotate
from skimage import img_as_ubyte
import matplotlib.pyplot as plt
import numpy as np

# %%
image = io.imread('example.png')
#print(image.shape)
image = color.gray2rgb(image)

# %%
im_red = np.copy(image)
mask_r = im_red[:,:, 0] < 250
im_red[mask_r] = [255,0,0]
plt.imshow(im_red)
#print(im_red)

# %%
im_green = np.copy(image)
mask_g = im_green[:,:, 1] < 250
im_green[mask_r] = [0,255,0]
im_green = rotate(im_green, 90, mode = 'edge')
im_green = img_as_ubyte(im_green)
plt.imshow(im_green)
print(im_green)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
im_mixed = (im_red + im_green) % 255
#im_mixed = img_as_ubyte(im_mixed / 255)
plt.imshow(im_mixed)
